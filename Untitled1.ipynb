# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_pickle("./readyToGo")

# %%
values = df.values
groups = [2, 4, 5]
i = 1
# plot each column
plt.figure()
for group in groups:
	plt.subplot(len(groups), 1, i)
	plt.plot(values[:, group])
	plt.title(df.columns[group], y=0.5, loc='right')
	i += 1
plt.show()
